# %% [markdown]
# """ ANALISIS_2_EDUARDO_ALMARAZ_MALDONADO"""

# %%
# En primer lugar, veremos la "cabeza" de nuestra base de datos:

import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

filepath = 'synergy_logistics_database.csv'

datos = pd.read_csv(filepath, index_col="register_id")

# %%
datos.head()
# Out:
#             direction origin destination  year      date product  \
# register_id
# 1             Exports  Japan       China  2015  31/01/15    Cars
# 2             Exports  Japan       China  2015  01/02/15    Cars
# 3             Exports  Japan       China  2015  02/02/15    Cars
# 4             Exports  Japan       China  2015  03/02/15    Cars
# 5             Exports  Japan       China  2015  04/02/15    Cars
#
#             transport_mode company_name  total_value
# register_id
# 1                      Sea        Honda     33000000
# 2                      Sea        Honda     16000000
# 3                      Sea        Honda     29000000
# 4                      Sea        Honda     14000000
# 5                      Sea        Honda     17000000

# %%
# De manera análoga, observamos la "cola" de los mismos:

datos.tail()
# Out:
#             direction    origin destination  year      date       product  \
# register_id
# 19052         Imports     Japan   Singapore  2020  27/06/20  Gas turbines
# 19053         Imports  Malaysia   Singapore  2020  28/06/20  Gas turbines
# 19054         Imports  Malaysia   Singapore  2020  29/06/20  Gas turbines
# 19055         Imports  Malaysia   Singapore  2020  30/06/20  Gas turbines
# 19056         Imports  Malaysia   Singapore  2020  01/07/20  Gas turbines
#
#             transport_mode     company_name  total_value
# register_id
# 19052                  Sea  Union Energy Co      1000000
# 19053                  Sea  Union Energy Co      2000000
# 19054                  Sea  Union Energy Co     33000000
# 19055                  Sea  Union Energy Co     13000000
# 19056                  Sea  Union Energy Co     30000000

# %%
# La base de datos tiene la siguiente información:
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19056 entries, 1 to 19056
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   direction       19056 non-null  object
#  1   origin          19056 non-null  object
#  2   destination     19056 non-null  object
#  3   year            19056 non-null  int64
#  4   date            19056 non-null  object
#  5   product         19056 non-null  object
#  6   transport_mode  19056 non-null  object
#  7   company_name    19056 non-null  object
#  8   total_value     19056 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 1.5+ MB

# %% [markdown]
# Rutas de importación exportación
#
# Vamos a identificar las diez rutas con mayor valor total de importaciones y exportaciones

# %%
# Una lista con las diez rutas con mayor valor en el comercio exterior, de la menor a la mayor.

import pandas as pd
filepath = 'synergy_logistics_database.csv'

datos = pd.read_csv(filepath, index_col="register_id")

datos.sort_values('total_value').tail(10)
# Out:
#             direction       origin     destination  year      date  \
# register_id
# 6036          Exports       France  United Kingdom  2018  21/05/18
# 783           Exports        China          Mexico  2020  23/02/20
# 5980          Exports       France  United Kingdom  2018  26/03/18
# 807           Exports        China          Mexico  2020  18/03/20
# 6008          Exports       France  United Kingdom  2018  23/04/18
# 814           Exports        China          Mexico  2020  25/03/20
# 6154          Exports       France         Belgium  2019  16/04/19
# 6098          Exports       France         Belgium  2019  19/02/19
# 5502          Exports  Netherlands         Belgium  2015  01/03/15
# 5646          Exports       France             USA  2016  20/02/16
#
#                      product transport_mode            company_name  \
# register_id
# 6036               Cosmetics            Sea              L Oreal Co
# ...

# %%
# Una lista con las diez rutas con mayor valor en el comercio exterior, de la mayor a la menor.

import pandas as pd
filepath = 'synergy_logistics_database.csv'

datos = pd.read_csv(filepath, index_col="register_id")

datos.nlargest(10, ['total_value'])
# Out:
#             direction       origin     destination  year      date  \
# register_id
# 5646          Exports       France             USA  2016  20/02/16
# 5502          Exports  Netherlands         Belgium  2015  01/03/15
# 6098          Exports       France         Belgium  2019  19/02/19
# 6154          Exports       France         Belgium  2019  16/04/19
# 814           Exports        China          Mexico  2020  25/03/20
# 6008          Exports       France  United Kingdom  2018  23/04/18
# 807           Exports        China          Mexico  2020  18/03/20
# 5980          Exports       France  United Kingdom  2018  26/03/18
# 783           Exports        China          Mexico  2020  23/02/20
# 6036          Exports       France  United Kingdom  2018  21/05/18
#
#                      product transport_mode            company_name  \
# register_id
# 5646               Cosmetics            Sea            Klorane Corp
# ...

# %%
# Medios de transporte más común en la base de datos:
datos.transport_mode.value_counts().head()
# Out:
# Sea     10688
# Rail     3381
# Road     2598
# Air      2389
# Name: transport_mode, dtype: int64

# %%
# A manera visual, podemos contrastar la preferencia para el traslado de mercancías:
plt.figure(figsize=(16,6))


# Gráfico para los tipos de transporte
sns.catplot(x='transport_mode', data=datos,kind='count')

# %% [markdown]
# Ahora, vamos a obtener una gráfica para conocer cuáles son los países que tienen más participación en el valor total de las de las exportaciones e importaciones:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

datos=pd.read_csv('synergy_logistics_database.csv')
df=pd.DataFrame(datos)
df.groupby('origin')['total_value'].sum().plot(kind='bar', legend='Reverse')
plt.xlabel(Miles)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-241e8605f552> in <module>
#       6 df=pd.DataFrame(datos)
#       7 df.groupby('origin')['total_value'].sum().plot(kind='bar', legend='Reverse')
# ----> 8 plt.xlabel(Miles)
#
# NameError: name 'Miles' is not defined

# %%
# En la siguiente gráfica, conoceremos las naciones que generan el 80 % de 
# las exportaciones:


df.groupby('origin')['total_value'].sum().plot(kind='pie', autopct="%0.1f %%", cmap='Paired')
plt.axis("equal")
plt.ylabel("País de origen")
# Out:
# Text(0, 0.5, 'País de origen')

# %%
# En este otro gráfico, vemos cuáles son los principales destinos de las mercancías:

df.groupby('destination')['total_value'].sum().plot(kind='pie', autopct="%0.1f %%", cmap='Paired')
plt.axis("equal")
plt.ylabel("País destino")
# Out:
# Text(0, 0.5, 'País destino')
